# %% [markdown]
# <a href="https://colab.research.google.com/github/tringuyenCoding/MachineLearning/blob/colab/Part_4_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPLEMENTING A NEURAL NETWORK MODEL USING KERAS
# Instructions:
# - Start the kernel: In the menu bar, select Kernel -> Restart kernel.
# - Complete all sections with the comment `YOUR CODE HERE`.
# - Run all code blocks to check the implementation: In the menu bar, select Cell -> Run All.

# %% [markdown]
# A machine learning model should have at least the following 7 methods:
#
# - `__init__`: the constructor function in object-oriented programming, used to initialize default parameters or the starting parameters of a model. In the initial exercises, the constructor may not be used for simplicity.
# - `build`: constructs the architecture of the model.
# - `train`: starts the training process of the model.
# - `save`: saves the trained model.
# - `load`: loads a pretrained model from a file.
# - `summary`: prints a summary of the model's architecture.
# - `predict`: predicts the output value given input data.

# %%
# The general implementation of the model includes 7 basic methods.
# Note: This model is just a suggestion and not mandatory.
# However, in the exercise section, it is required to adhere to these method names.
class MyModel:
    # constructor
    def __init__(self):
        return None

    # Implement architecture of the model
    def build(self):
        return None

    # Train the defined model with training and validation data
    def train(self):
        return None

    # Save the trained model to file
    def save(self, model_path):
        return None

    # Load pretrained model from file
    def load(self):
        return None
    # Visualize your model
    def summary(self):
        return None

    # Apply your model with new input data
    def predict(self):
        return None

# %% [markdown]
# ## Step 1. Import the Keras libraries
#
# First, let's import the necessary libraries, modules, and functions from `Keras`:
# - `Input`: to receive input data for the model
# - `Dense`: also known as the Fully Connected layer, an important component of Neural Network-based models.
# - `Model`: this is the model object class used to encapsulate the input and output layers, then train with the `fit` method and predict results with `predict`.
# - `load_model`: a function used to load a model from a file.

# %%
from keras.layers import Input, Dense
from keras import Model
import tensorflow as tf
from keras.models import load_model
import numpy as np

# %% [markdown]
# ## Step 2. Implementing the Neural Network model
#
# Next, we will use the `MyModel` object framework presented in the previous section to implement the **Neural Network** model. The main method that needs to be implemented for this exercise is `def build()`. The remaining methods have already been implemented, and you should read and understand their meanings and how to use them for future reference.
#
# <p align="center">
#   <img src="NeuralNet.png" />
# </p>

# %%
# Neural Network
class NeuralNetwork:
    def __init__(self): # Self is similar to your 'this' pointer in C++
        return None

    def build(self, input_dim, output_dim, n_hidden, n_neurons):
        # `input_dim`: Size of the input feature
        # `output_dim`: Number of classes to classify
        # `n_hidden`: Number of hidden layers
        # `n_neurons`: Number of neurons per hidden layer

        # Khởi tạo model
        self.model = None

        # Implement to define the ARCHITECTURE OF THE MODEL and store it in the `self.model` attribute
        # with the following object variables:
        #   - create a variable `input` using the `Input` object of Keras,
        #     passing the input dimension `input_dim`
        #   - create `n_hidden` hidden layers, where each hidden layer has `n_neurons` and uses bias
        #     activation function is `sigmoid`. The output of each hidden layer is the input of the next hidden layer.
        #   - create a variable `output` using the `Dense` object of Keras,
        #     passing the parameters: output dimension (note MULTI-CLASSIFICATION),
        #     using bias, using activation function `softmax`. The input of the output layer is the last hidden layer.
        # After this step, self.model will wrap the `input` and `output` variables to create the model.
        ### YOUR CODE HERE
        input = Input(shape=(input_dim,))
        hidden = Dense(n_neurons, activation='sigmoid',use_bias=True)(input)
        for _ in range(1,n_hidden ,1):
            hidden = Dense(n_neurons, activation='sigmoid',use_bias=True)(hidden)
        output = Dense(output_dim, activation = 'softmax', use_bias = True)(hidden)
        self.model = Model(inputs=input, outputs=output)
        return self.model

    def train(self, x_train, y_train, epochs=500):
        # Initialize with default values: `epochs=50`, `learning_rate=0.05`
        opt = tf.keras.optimizers.SGD(learning_rate=0.05) # Stochastic Gradient Descent
        self.model.compile(optimizer=opt, loss='categorical_crossentropy') # CCE loss
        return self.model.fit(x_train, y_train, epochs=epochs)

    def save(self, model_file):
        return self.model.save(model_file)

    def load(self, model_file):
        self.model = load_model(model_file)

    def summary(self):
        self.model.summary()

    def predict(self, x_test):
        return self.model.predict(x_test)

    def get_weights(self, layer_id):
        return self.model.layers[layer_id].get_weights()

# %% [markdown]
# Next, we will instantiate the NeuralNetwork object and test whether the `build` method has been implemented correctly.

# %%
nn = NeuralNetwork()
# In this example, we will initialize the input as a 1000-dimensional vector,
# and the problem requires classification of 20 classes. The number of hidden layers is 3
# and the number of neurons in each hidden layer is 10.
nn.build(1000, 20, 3, 10)

# %%
# # Check the overall network architecture consisting of 2 + 3 = 5 layers: Input, 3 hidden layers, and Output.
assert len(nn.model.layers)==5
assert str(type(nn.model.layers[0]))== "<class 'keras.engine.input_layer.InputLayer'>"
assert str(type(nn.model.layers[1]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[2]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[3]))== "<class 'keras.layers.core.dense.Dense'>"
assert str(type(nn.model.layers[4]))== "<class 'keras.layers.core.dense.Dense'>"
assert nn.model.layers[0].input_shape[0][1] == 1000
assert nn.model.layers[-1].output_shape[1] == 20
assert nn.model.layers[1].use_bias == True
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-1a37c47899ae> in <cell line: 3>()
#       1 # # Check the overall network architecture consisting of 2 + 3 = 5 layers: Input, 3 hidden layers, and Output.
#       2 assert len(nn.model.layers)==5
# ----> 3 assert str(type(nn.model.layers[0]))== "<class 'keras.engine.input_layer.InputLayer'>"
#       4 assert str(type(nn.model.layers[1]))== "<class 'keras.layers.core.dense.Dense'>"
#       5 assert str(type(nn.model.layers[2]))== "<class 'keras.layers.core.dense.Dense'>"
#
# AssertionError:

# %%
# Test with hidden test cases.

# %% [markdown]
# ## Step 3. Generate Sample Data (Toy Example)
# Next, we will generate sample data for training and testing.
#
# The data is generated as randomly scattered points around 4 clusters:
# - [10, -2]
# - [2, 8]
# - [12, 8]
# - [-2, 0]
#
# Note that these 4 clusters are far enough apart so that when adding random noise,
# the points belonging to these 4 clusters still do not intersect with each other.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of classes: 4
K = 4
# Create a dataset consisting of 4 points
# S1, S2, S3, S4 are the centers of the 4 classes
S1= np.array([[10,-2]])
S2= np.array([[2,8]])
S3= np.array([[12,8]])
S4= np.array([[-2,0]])

# 50 samples for each class
n_sample = 50
# Generate points with random noise around the 4 centers
pts1 = S1 + np.random.normal(0, 1.5, size=(n_sample,2))
pts2 = S2 + np.random.normal(0, 1.5, size=(n_sample,2))
pts3 = S3 + np.random.normal(0, 1.5, size=(n_sample,2))
pts4 = S4 + np.random.normal(0, 1.5, size=(n_sample,2))

# Concatenate all samples into a single data block X (input features) and Y (labels)
X_train = np.concatenate((pts1, pts2, pts3, pts4))
# Concatenate data labels to a single input variable Y
Y_train = np.concatenate(([0]*n_sample, [1]*n_sample, [2]*n_sample, [3]*n_sample))

# Convert Y from label form to one-hot vectors
Y_train = Y_train.astype(int)
Y_oh = np.zeros((Y_train.size, Y_train.max()+1 ))
Y_oh[np.arange(Y_train.size), Y_train] = 1

# Visualize the data using colored circles: red, green, blue, and yellow
plt.plot(pts1[:,0], pts1[:,1], 'ro')
plt.plot(pts2[:,0], pts2[:,1], 'go')
plt.plot(pts3[:,0], pts3[:,1], 'bo')
plt.plot(pts4[:,0], pts4[:,1], 'yo')
plt.show()

# %% [markdown]
# ## Step 4. Training the Model with Sample Data
#
# Next, we will initialize the model to match the generated sample data. The architecture of the model should be compatible with the dimensions of the sample data.

# %%
nn = NeuralNetwork()

# Call the `build` method for the `sr` object and pass the corresponding input parameters
# based on the generated training data in the previous code block.
# According to you, what are `input_dim` and `output_dim`?
# For the hidden layers, we initialize 1 hidden layer and 3 neurons for each hidden layer.

### YOUR CODE HERE
nn.build(input_dim=2, output_dim=4, n_hidden=1, n_neurons=3)
# To display the architecture of the model, we call the `summary` method.
print("The architecture of the Neural Network model:")
nn.summary()
# Out:
# The architecture of the Neural Network model:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_4 (Dense)             (None, 3)                 9
#
#  dense_5 (Dense)             (None, 4)                 16
#
# =================================================================
# Total params: 25 (100.00 Byte)
# Trainable params: 25 (100.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Check the result when the `nn` object calls the `build` method

# %%
# To train the model, we call the `train` method with the generated sample data.
# If the `build` step of the model is called correctly, the subsequent `train` step will be successful.
# NOTE: Here we use the one-hot encoded form Y_oh as the output instead of the label form.
hist = nn.train(X_train, Y_oh)
# Out:
# Epoch 1/500
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6450
# Epoch 2/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.5506
# Epoch 3/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.4501
# Epoch 4/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3850
# Epoch 5/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3428
# Epoch 6/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3088
# Epoch 7/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2802
# Epoch 8/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2509
# Epoch 9/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2241
# Epoch 10/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1996
# Epoch 11/500
# 7/7 [==============================] - 0s 3ms/step - loss: 1.1758
# Epoch 12/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1528
# Epoch 13/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1313
# Epoch 14/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1109
# Epoch 15/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0918
# Epoch 16/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0721
# Epoch 17/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0550
# Epoch 18/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0377
# Epoch 19/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0207
# Epoch 20/500
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0045
# Epoch 21/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9888
# Epoch 22/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9738
# Epoch 23/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9594
# Epoch 24/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9459
# Epoch 25/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9319
# Epoch 26/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.9190
# Epoch 27/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.9067
# Epoch 28/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8945
# Epoch 29/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8822
# Epoch 30/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8711
# Epoch 31/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8596
# Epoch 32/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8493
# Epoch 33/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8389
# Epoch 34/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8290
# Epoch 35/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8194
# Epoch 36/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8105
# Epoch 37/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.8015
# Epoch 38/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7923
# Epoch 39/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7838
# Epoch 40/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7757
# Epoch 41/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7676
# Epoch 42/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7598
# Epoch 43/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7525
# Epoch 44/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7453
# Epoch 45/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7382
# Epoch 46/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7313
# Epoch 47/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7251
# Epoch 48/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.7187
# Epoch 49/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7121
# Epoch 50/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7061
# Epoch 51/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7002
# Epoch 52/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6945
# Epoch 53/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6888
# Epoch 54/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6835
# Epoch 55/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6782
# Epoch 56/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6735
# Epoch 57/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6680
# Epoch 58/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6632
# Epoch 59/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6586
# Epoch 60/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6536
# Epoch 61/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6494
# Epoch 62/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6451
# Epoch 63/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6407
# Epoch 64/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6364
# Epoch 65/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6324
# Epoch 66/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6285
# Epoch 67/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6248
# Epoch 68/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6210
# Epoch 69/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6171
# Epoch 70/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6137
# Epoch 71/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6102
# Epoch 72/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6065
# Epoch 73/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6030
# Epoch 74/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5999
# Epoch 75/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5966
# Epoch 76/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5938
# Epoch 77/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5905
# Epoch 78/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5872
# Epoch 79/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5846
# Epoch 80/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5816
# Epoch 81/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5787
# Epoch 82/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5762
# Epoch 83/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5733
# Epoch 84/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5708
# Epoch 85/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5684
# Epoch 86/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5657
# Epoch 87/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5634
# Epoch 88/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5607
# Epoch 89/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5583
# Epoch 90/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5562
# Epoch 91/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5536
# Epoch 92/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5514
# Epoch 93/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5493
# Epoch 94/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5472
# Epoch 95/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5449
# Epoch 96/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5428
# Epoch 97/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5408
# Epoch 98/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5387
# Epoch 99/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5373
# Epoch 100/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5349
# Epoch 101/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5329
# Epoch 102/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5311
# Epoch 103/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5293
# Epoch 104/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5280
# Epoch 105/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5259
# Epoch 106/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5243
# Epoch 107/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5225
# Epoch 108/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5210
# Epoch 109/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5192
# Epoch 110/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5175
# Epoch 111/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5160
# Epoch 112/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5146
# Epoch 113/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5131
# Epoch 114/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5118
# Epoch 115/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5103
# Epoch 116/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.5090
# Epoch 117/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5071
# Epoch 118/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5057
# Epoch 119/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5043
# Epoch 120/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5029
# Epoch 121/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.5018
# Epoch 122/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5002
# Epoch 123/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4990
# Epoch 124/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4978
# Epoch 125/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4966
# Epoch 126/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4952
# Epoch 127/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4941
# Epoch 128/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4927
# Epoch 129/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4916
# Epoch 130/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4904
# Epoch 131/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4892
# Epoch 132/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4882
# Epoch 133/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4871
# Epoch 134/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4859
# Epoch 135/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4849
# Epoch 136/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4837
# Epoch 137/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4827
# Epoch 138/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4817
# Epoch 139/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4806
# Epoch 140/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4798
# Epoch 141/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4790
# Epoch 142/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4777
# Epoch 143/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4768
# Epoch 144/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4759
# Epoch 145/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4749
# Epoch 146/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4739
# Epoch 147/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4730
# Epoch 148/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4720
# Epoch 149/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4712
# Epoch 150/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4703
# Epoch 151/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4693
# Epoch 152/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4686
# Epoch 153/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4678
# Epoch 154/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4670
# Epoch 155/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4660
# Epoch 156/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4653
# Epoch 157/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4646
# Epoch 158/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4638
# Epoch 159/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4630
# Epoch 160/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4622
# Epoch 161/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4614
# Epoch 162/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4607
# Epoch 163/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4600
# Epoch 164/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4592
# Epoch 165/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4587
# Epoch 166/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4578
# Epoch 167/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4570
# Epoch 168/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4565
# Epoch 169/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4558
# Epoch 170/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4550
# Epoch 171/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4545
# Epoch 172/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4537
# Epoch 173/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4529
# Epoch 174/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4524
# Epoch 175/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4517
# Epoch 176/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4510
# Epoch 177/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4505
# Epoch 178/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4500
# Epoch 179/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4492
# Epoch 180/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4486
# Epoch 181/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4479
# Epoch 182/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4473
# Epoch 183/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4469
# Epoch 184/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4460
# Epoch 185/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4456
# Epoch 186/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4451
# Epoch 187/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4444
# Epoch 188/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4439
# Epoch 189/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4434
# Epoch 190/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4428
# Epoch 191/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4423
# Epoch 192/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4418
# Epoch 193/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4411
# Epoch 194/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4405
# Epoch 195/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4405
# Epoch 196/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4395
# Epoch 197/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4391
# Epoch 198/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4386
# Epoch 199/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4381
# Epoch 200/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4375
# Epoch 201/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4371
# Epoch 202/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4365
# Epoch 203/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4360
# Epoch 204/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4356
# Epoch 205/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4351
# Epoch 206/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4347
# Epoch 207/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4344
# Epoch 208/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4339
# Epoch 209/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4334
# Epoch 210/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4329
# Epoch 211/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4324
# Epoch 212/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4319
# Epoch 213/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4316
# Epoch 214/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4314
# Epoch 215/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4308
# Epoch 216/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4304
# Epoch 217/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4299
# Epoch 218/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4297
# Epoch 219/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4292
# Epoch 220/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4287
# Epoch 221/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4284
# Epoch 222/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4281
# Epoch 223/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4274
# Epoch 224/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4271
# Epoch 225/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4266
# Epoch 226/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4263
# Epoch 227/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4258
# Epoch 228/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4255
# Epoch 229/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4254
# Epoch 230/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4248
# Epoch 231/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4245
# Epoch 232/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4245
# Epoch 233/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4240
# Epoch 234/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4235
# Epoch 235/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4231
# Epoch 236/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4226
# Epoch 237/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4226
# Epoch 238/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4221
# Epoch 239/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4215
# Epoch 240/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4212
# Epoch 241/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4210
# Epoch 242/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4205
# Epoch 243/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4204
# Epoch 244/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4198
# Epoch 245/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4197
# Epoch 246/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4193
# Epoch 247/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4193
# Epoch 248/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4186
# Epoch 249/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4184
# Epoch 250/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4181
# Epoch 251/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4176
# Epoch 252/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4173
# Epoch 253/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4170
# Epoch 254/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4168
# Epoch 255/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4165
# Epoch 256/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4163
# Epoch 257/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4159
# Epoch 258/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4156
# Epoch 259/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4154
# Epoch 260/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4151
# Epoch 261/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4146
# Epoch 262/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4144
# Epoch 263/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4144
# Epoch 264/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4140
# Epoch 265/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4136
# Epoch 266/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4132
# Epoch 267/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4130
# Epoch 268/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4128
# Epoch 269/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4124
# Epoch 270/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4122
# Epoch 271/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4119
# Epoch 272/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4117
# Epoch 273/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4115
# Epoch 274/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4113
# Epoch 275/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4110
# Epoch 276/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4107
# Epoch 277/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4105
# Epoch 278/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4102
# Epoch 279/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4100
# Epoch 280/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4096
# Epoch 281/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4095
# Epoch 282/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4092
# Epoch 283/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4089
# Epoch 284/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4086
# Epoch 285/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4087
# Epoch 286/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4081
# Epoch 287/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4080
# Epoch 288/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4078
# Epoch 289/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4075
# Epoch 290/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4074
# Epoch 291/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4071
# Epoch 292/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4069
# Epoch 293/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4068
# Epoch 294/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4064
# Epoch 295/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4061
# Epoch 296/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4058
# Epoch 297/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4058
# Epoch 298/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4056
# Epoch 299/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4053
# Epoch 300/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4055
# Epoch 301/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4050
# Epoch 302/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4048
# Epoch 303/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4045
# Epoch 304/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4041
# Epoch 305/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4041
# Epoch 306/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4038
# Epoch 307/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4036
# Epoch 308/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4033
# Epoch 309/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4032
# Epoch 310/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4030
# Epoch 311/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4031
# Epoch 312/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4030
# Epoch 313/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4024
# Epoch 314/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4022
# Epoch 315/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4022
# Epoch 316/500
# 7/7 [==============================] - 0s 11ms/step - loss: 0.4018
# Epoch 317/500
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4016
# Epoch 318/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4016
# Epoch 319/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4013
# Epoch 320/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4011
# Epoch 321/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4010
# Epoch 322/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4008
# Epoch 323/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4004
# Epoch 324/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4003
# Epoch 325/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.4002
# Epoch 326/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3999
# Epoch 327/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3999
# Epoch 328/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3995
# Epoch 329/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3993
# Epoch 330/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3993
# Epoch 331/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3992
# Epoch 332/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3988
# Epoch 333/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3987
# Epoch 334/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3986
# Epoch 335/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3985
# Epoch 336/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3983
# Epoch 337/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3979
# Epoch 338/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3979
# Epoch 339/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3977
# Epoch 340/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3976
# Epoch 341/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3973
# Epoch 342/500
# 7/7 [==============================] - 0s 8ms/step - loss: 0.3972
# Epoch 343/500
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3970
# Epoch 344/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3972
# Epoch 345/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3966
# Epoch 346/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3965
# Epoch 347/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3965
# Epoch 348/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3964
# Epoch 349/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3961
# Epoch 350/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3960
# Epoch 351/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3957
# Epoch 352/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3956
# Epoch 353/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3957
# Epoch 354/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3954
# Epoch 355/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3952
# Epoch 356/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3951
# Epoch 357/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3948
# Epoch 358/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3946
# Epoch 359/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3946
# Epoch 360/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3946
# Epoch 361/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3944
# Epoch 362/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3943
# Epoch 363/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3939
# Epoch 364/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3938
# Epoch 365/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3937
# Epoch 366/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3936
# Epoch 367/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3934
# Epoch 368/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3933
# Epoch 369/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3931
# Epoch 370/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3931
# Epoch 371/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3930
# Epoch 372/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3927
# Epoch 373/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3928
# Epoch 374/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3924
# Epoch 375/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3924
# Epoch 376/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3922
# Epoch 377/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3920
# Epoch 378/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3919
# Epoch 379/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3919
# Epoch 380/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3920
# Epoch 381/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3916
# Epoch 382/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3915
# Epoch 383/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3913
# Epoch 384/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3914
# Epoch 385/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3910
# Epoch 386/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3910
# Epoch 387/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3908
# Epoch 388/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3907
# Epoch 389/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3906
# Epoch 390/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3905
# Epoch 391/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3903
# Epoch 392/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3901
# Epoch 393/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3901
# Epoch 394/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3899
# Epoch 395/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3901
# Epoch 396/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3897
# Epoch 397/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3897
# Epoch 398/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3895
# Epoch 399/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3894
# Epoch 400/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3893
# Epoch 401/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3892
# Epoch 402/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3890
# Epoch 403/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3888
# Epoch 404/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3888
# Epoch 405/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3886
# Epoch 406/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3885
# Epoch 407/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3884
# Epoch 408/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3883
# Epoch 409/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3881
# Epoch 410/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3881
# Epoch 411/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3880
# Epoch 412/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3879
# Epoch 413/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3877
# Epoch 414/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3875
# Epoch 415/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3875
# Epoch 416/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3874
# Epoch 417/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3875
# Epoch 418/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3873
# Epoch 419/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3872
# Epoch 420/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3872
# Epoch 421/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3871
# Epoch 422/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3869
# Epoch 423/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3866
# Epoch 424/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3865
# Epoch 425/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3864
# Epoch 426/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3864
# Epoch 427/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3862
# Epoch 428/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3862
# Epoch 429/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3860
# Epoch 430/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3859
# Epoch 431/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3859
# Epoch 432/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3858
# Epoch 433/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3857
# Epoch 434/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3859
# Epoch 435/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3857
# Epoch 436/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3853
# Epoch 437/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3853
# Epoch 438/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3853
# Epoch 439/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3850
# Epoch 440/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3851
# Epoch 441/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3850
# Epoch 442/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3849
# Epoch 443/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3847
# Epoch 444/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3847
# Epoch 445/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3845
# Epoch 446/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3844
# Epoch 447/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3844
# Epoch 448/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3842
# Epoch 449/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3841
# Epoch 450/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3841
# Epoch 451/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3841
# Epoch 452/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3838
# Epoch 453/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3838
# Epoch 454/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3838
# Epoch 455/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3836
# Epoch 456/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3837
# Epoch 457/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3836
# Epoch 458/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3835
# Epoch 459/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3834
# Epoch 460/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3831
# Epoch 461/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3830
# Epoch 462/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3831
# Epoch 463/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3828
# Epoch 464/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3828
# Epoch 465/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3828
# Epoch 466/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3826
# Epoch 467/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3828
# Epoch 468/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3826
# Epoch 469/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3828
# Epoch 470/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3823
# Epoch 471/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3824
# Epoch 472/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3821
# Epoch 473/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3825
# Epoch 474/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3820
# Epoch 475/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3819
# Epoch 476/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3820
# Epoch 477/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3818
# Epoch 478/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3816
# Epoch 479/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3816
# Epoch 480/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3817
# Epoch 481/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3814
# Epoch 482/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3815
# Epoch 483/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3812
# Epoch 484/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3812
# Epoch 485/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3813
# Epoch 486/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3811
# Epoch 487/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3809
# Epoch 488/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3811
# Epoch 489/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3807
# Epoch 490/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3808
# Epoch 491/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3806
# Epoch 492/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3806
# Epoch 493/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3806
# Epoch 494/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3803
# Epoch 495/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3803
# Epoch 496/500
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3803
# Epoch 497/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3804
# Epoch 498/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3801
# Epoch 499/500
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3800
# Epoch 500/500
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3803

# %%
# Display the loss over the number of epochs
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# After training, we save the model for future reuse.
# Note: the two methods `save` and `load` are used when we want to reuse the model multiple times without retraining.
nn.save('neural_network_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Step 5. Visualize the model and make predictions with test data

# %%
# Initialize a new object and call the `load` method to load the model from a file
pretrain_nn = NeuralNetwork()
pretrain_nn.load('neural_network_model.h5')

# %%
# Print the optimized parameters of the last layer
theta = pretrain_nn.get_weights(-1)
print('Optimized parameters: ')
print(theta)
# Out:
# Optimized parameters:
# [array([[-0.8303636 , -1.0516405 , -0.4986393 ,  4.0099354 ],
#        [-0.24731775, -2.0603292 , -0.9973321 ,  2.3426619 ],
#        [-2.9172754 ,  4.7875056 , -2.4315984 ,  0.9354713 ]],
#       dtype=float32), array([ 1.7364073, -1.414773 ,  1.7471334, -2.0687733], dtype=float32)]

# %%
# Visualize the data and the trained model
# Idea: Sample dense points within the range of the training data
# Then use the model to make predictions and display the results

# `colors` are the markers used to visualize the test results
colors = ['r+', 'g+', 'b+', 'y+']
# `gt_colors` are the markers used to visualize the training data
gt_colors = ['ro', 'go', 'bo', 'yo']

# Sample dense points
x = np.arange(-8, 17, 1)
y = np.arange(-8, 17, 1)
xx, yy = np.meshgrid(x,y)

xx = xx.reshape(-1)
yy = yy.reshape(-1)

# Generate dense test data
X_test = np.concatenate([[xx],[yy]], axis=0).T
Y_pred = pretrain_nn.predict(X_test)

for i in range(len(xx)):
    plt.plot(xx[i],yy[i], colors[np.argmax(Y_pred[i])])
plt.plot(pts1[:,0], pts1[:,1], gt_colors[0])
plt.plot(pts2[:,0], pts2[:,1], gt_colors[1])
plt.plot(pts3[:,0], pts3[:,1], gt_colors[2])
plt.plot(pts4[:,0], pts4[:,1], gt_colors[3])
plt.show()
# Out:
# 20/20 [==============================] - 0s 1ms/step

# %% [markdown]
# We can see that the 2D plane has been classified using the previously trained Neural Network model. Based on the plot, we can observe that the results are quite accurate, except for some points at the boundaries between classes.

# %% [markdown]
# ## Step 6. Testing with MNIST dataset
#
# MNIST is a classic dataset of handwritten digits widely used in machine learning. To download and use this dataset, it is incredibly simple with just 2 lines of code:

# %%
# Prepare MNIST dataset
from keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# To gain a better understanding of this dataset, let's visualize the data by displaying images and examining their dimensions.

# %%
plt.imshow(x_train[1234])
print('The label of the 1234th data sample is: ', y_train[1234])
print('The size of the training images is: ', x_train[1234].shape)
print('The number of image points when transformed into a vector is: ',
      x_train[1234].shape[0]*x_train[1234].shape[1])
# Out:
# The label of the 1234th data sample is:  3
# The size of the training images is:  (28, 28)
# The number of image points when transformed into a vector is:  784

# %% [markdown]
# To preprocess the data before training the model, you can perform the following steps:
#
# 1. Convert the output labels to one-hot vectors: This can be done using one-hot encoding, where each label is represented as a binary vector with a value of 1 in the corresponding class index and 0 in other indices.
#
# 2. Normalize the input data to the range [0-1]: This can be achieved by dividing each pixel value by the maximum pixel value (255 in the case of MNIST dataset), so that all pixel values are scaled to the range [0-1].
#
# Performing these preprocessing steps will help in improving the training process and the performance of the model.

# %%
# The function to convert the output from label format to one-hot vector
def onehot(y):
    oh = np.zeros((y.shape[0], y.max()+1))
    oh[np.arange(y.shape[0]), y] = 1
    return oh

y_train_oh = onehot(y_train)
y_test_oh = onehot(y_test)

# Normalize the input data for both the training and testing datasets.
n_train_sample, h, w = x_train.shape
n_test_sample, _,_ = x_test.shape # Ensure that all samples have the same width and height dimensions.

x_train = (x_train.astype('float32')) / 255.0
x_test = (x_test.astype('float32')) / 255.0
x_train_vec = x_train.reshape((n_train_sample, w*h))
x_test_vec = x_test.reshape((n_test_sample, w*h))

# %% [markdown]
# To initialize a model from scratch that is suitable for the MNIST dataset, with the following configuration details regarding the hidden layers:
#
# - 2 hidden layers
# - 100 neurons in each hidden layer
# - Training for 30 epochs

# %%
nn4mnist = NeuralNetwork()

# Completing the following code snippet by using the variable `nn4mnist` to call the `build` and `train` methods. Note: Use the appropriate parameters as specified.

### YOUR CODE HERE
nn4mnist.build(input_dim=784, output_dim=10, n_hidden=2, n_neurons=100)
hist = nn4mnist.train(x_train_vec, y_train_oh, 30)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.3226
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4603
# Epoch 3/30
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3474
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3036
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2750
# Epoch 6/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2526
# Epoch 7/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2336
# Epoch 8/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2170
# Epoch 9/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2022
# Epoch 10/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1893
# Epoch 11/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1776
# Epoch 12/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1673
# Epoch 13/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1573
# Epoch 14/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1485
# Epoch 15/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1404
# Epoch 16/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1335
# Epoch 17/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1267
# Epoch 18/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1207
# Epoch 19/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1147
# Epoch 20/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1096
# Epoch 21/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1047
# Epoch 22/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0999
# Epoch 23/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0958
# Epoch 24/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0919
# Epoch 25/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0882
# Epoch 26/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0848
# Epoch 27/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0813
# Epoch 28/30
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0785
# Epoch 29/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0754
# Epoch 30/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0727

# %%
# Visualizing the loss values during the training process.
plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %%
# Preliminary check of the variable `hist`: if the initialization and training process are successful, the following tests should pass.
print(len(hist.history['loss']))
assert hist is not None
assert 'loss' in hist.history
assert len(hist.history['loss']) == 30
# Out:
# 30

# %%
# Test with hidden test cases.

# %% [markdown]
# After training the model, we can use it to make predictions on the test data. Let's make predictions on a sample test data:

# %%
pred = nn4mnist.predict(x_test_vec)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Let's visualize a sample test data (e.g., the 50th sample).

# %%
# Show the 50-th test sample
test_id = 50
plt.imshow(x_test[test_id])
print('Label of the data: ', y_test[test_id])
print('Predicted label of the data: ', np.argmax(pred[test_id]))
# Out:
# Label of the data:  6
# Predicted label of the data:  6
